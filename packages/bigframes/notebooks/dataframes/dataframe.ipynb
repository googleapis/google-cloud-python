# %% [markdown]
# # Demo to Show DataFrame Operations

# %%
# On the instance where you are running jupyter,
# authenticate with gcloud first:
#
#     gcloud auth application-default login

import bigframes.pandas as bpd

bpd.options.bigquery.location = "US"

# %%
df = bpd.read_gbq("bigquery-public-data.baseball.schedules")
# Out:
# HTML(value='Query job ccb31707-38d2-4d93-8502-e39352f322a3 is RUNNING. <a target="_blank" href="https://consol…
# HTML(value='Query job a71b5936-09b6-4e35-afeb-11fca4805832 is RUNNING. <a target="_blank" href="https://consol…

# %% [markdown]
# ### Select a subset of the DF

# %%
df = df[["gameId", "year", "homeTeamName", "awayTeamName", "duration_minutes"]]

# %%
df
# Here starts real execution, may take a while
# Out:
# HTML(value='Query job fa4bad97-52d0-4117-85f4-9bb911520164 is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job fdc644e2-c008-485a-90b2-dc64e5c81f3b is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  year  homeTeamName awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [2431 rows x 5 columns]

# %%
df.shape
# Out:
# (2431, 5)

# %% [markdown]
# ### Retrieve properties of the DF.

# %%
df.dtypes
# Out:
# gameId              string[pyarrow]
# year                          Int64
# homeTeamName        string[pyarrow]
# awayTeamName        string[pyarrow]
# duration_minutes              Int64
# dtype: object

# %%
df.columns
# Out:
# Index(['gameId', 'year', 'homeTeamName', 'awayTeamName', 'duration_minutes'], dtype='object')

# %% [markdown]
# ### Add a new column

# %%
df = df.assign(title=df['homeTeamName'] + " vs " + df['awayTeamName'])
df
# Out:
# HTML(value='Query job c4b8deed-0c47-4ce7-b013-d8b24997851a is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job e6830838-99ae-4162-a47f-2185bb9c1f27 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  year  homeTeamName awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes                 title
# 0                187       Marlins vs Cubs
# 1                189       Marlins vs Cubs
# 2                165        Braves vs Cubs
# 3                222        Braves vs Cubs
# 4                164      Phillies vs Cubs
# 5                201  Diamondbacks vs Cubs
# 6                173     Athletics vs Cubs
# 7                176     Athletics vs Cubs
# 8                180       Rockies vs Cubs
# 9                157     Cardinals vs Cubs
# 10               218     Cardinals vs Cubs
# 11               160     Cardinals vs Cubs
# 12               178       Pirates vs Cubs
# 13               205       Pirates vs Cubs
# 14               197        Giants vs Cubs
# 15               198          Reds vs Cubs
# 16               188          Reds vs Cubs
# 17               188          Reds vs Cubs
# 18               194          Reds vs Cubs
# 19               175        Padres vs Cubs
# 20               257     Nationals vs Cubs
# 21               178       Brewers vs Cubs
# 22               171       Brewers vs Cubs
# 23               248       Brewers vs Cubs
# 24               174        Astros vs Cubs
# ...
#
# [2431 rows x 6 columns]

# %% [markdown]
# ### Manipulate the column

# %%
df = df.rename(columns={"title": "headline"})
df
# Out:
# HTML(value='Query job 2062db30-30ae-42cf-8afa-9b8f3493fd98 is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job 9c36c84f-e672-46e1-a134-7ef2c2e60b4e is DONE. 0 Bytes processed. <a target="_blank" href…
#                                   gameId  year  homeTeamName awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes              headline
# 0                187       Marlins vs Cubs
# 1                189       Marlins vs Cubs
# 2                165        Braves vs Cubs
# 3                222        Braves vs Cubs
# 4                164      Phillies vs Cubs
# 5                201  Diamondbacks vs Cubs
# 6                173     Athletics vs Cubs
# 7                176     Athletics vs Cubs
# 8                180       Rockies vs Cubs
# 9                157     Cardinals vs Cubs
# 10               218     Cardinals vs Cubs
# 11               160     Cardinals vs Cubs
# 12               178       Pirates vs Cubs
# 13               205       Pirates vs Cubs
# 14               197        Giants vs Cubs
# 15               198          Reds vs Cubs
# 16               188          Reds vs Cubs
# 17               188          Reds vs Cubs
# 18               194          Reds vs Cubs
# 19               175        Padres vs Cubs
# 20               257     Nationals vs Cubs
# 21               178       Brewers vs Cubs
# 22               171       Brewers vs Cubs
# 23               248       Brewers vs Cubs
# 24               174        Astros vs Cubs
# ...
#
# [2431 rows x 6 columns]

# %%
df = df.drop(columns="headline")

# %%
df
# Out:
# HTML(value='Query job f0ed19be-b1f5-4333-a51f-3c7872a2bbc6 is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job 863e72d3-b421-4e53-98bb-9bf634fe9a71 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  year  homeTeamName awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [2431 rows x 5 columns]

# %% [markdown]
# ### Drop Nan values

# %%
df = df.dropna()
df
# Out:
# HTML(value='Query job e387be31-99fc-46a9-9de7-3bb83ff1f4fe is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job af23a9a2-151d-469a-a5c7-588ea60d1602 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  year  homeTeamName awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [2431 rows x 5 columns]

# %% [markdown]
# ### Join two DFs

# %%
df1 = df[["gameId", "homeTeamName"]]
df1
# Out:
# HTML(value='Query job b14b9796-f94d-48c0-a477-13f6b865e11d is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job 20f025c3-4d84-49e9-9fbd-d77eeb2c6e04 is RUNNING. <a target="_blank" href="https://consol…
#                                   gameId  homeTeamName
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf       Marlins
# 1   1f32b347-cbcb-4c31-a145-0e685306d168       Marlins
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43        Braves
# 3   8fbec734-a15a-42ab-8d51-60790de7750b        Braves
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd      Phillies
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  Diamondbacks
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce     Athletics
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d     Athletics
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01       Rockies
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba     Cardinals
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6     Cardinals
# 11  46463c50-0f5c-4dca-a661-dd194464e791     Cardinals
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f       Pirates
# 13  387630a3-a894-4327-baa1-b24ec1a654d9       Pirates
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556        Giants
# 15  34444c94-03ec-4d12-96af-68b8f399a22f          Reds
# 16  9580bffe-22e1-4975-978b-1b13e7505193          Reds
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3          Reds
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90          Reds
# 19  303703bb-b55f-476d-8faf-bf582169fb1d        Padres
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61     Nationals
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c       Brewers
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252       Brewers
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923       Brewers
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956        Astros
# ...
#
# [2431 rows x 2 columns]

# %%
df2 = df[["gameId", "awayTeamName"]].head(2)
df2
# Out:
# HTML(value='Query job fbd5deef-4c7f-4345-ab6c-28c3e24bd918 is DONE. 193.8 kB processed. <a target="_blank" hre…
# HTML(value='Query job ba580b64-ca65-4245-b17f-12fd382b2e2b is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                  gameId awayTeamName
# 0  e14b6493-9e7f-404f-840a-8a680cc364bf         Cubs
# 1  1f32b347-cbcb-4c31-a145-0e685306d168         Cubs
#
# [2 rows x 2 columns]

# %%
df1.merge(df2, on="gameId", how="inner")
# Out:
# HTML(value='Query job 3f54256f-7189-400b-8d47-5ce1f6fe92c0 is DONE. 193.8 kB processed. <a target="_blank" hre…
# HTML(value='Query job 57211b59-73c2-42d6-88bd-a614a8baf779 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                  gameId homeTeamName awayTeamName
# 0  e14b6493-9e7f-404f-840a-8a680cc364bf      Marlins         Cubs
# 1  1f32b347-cbcb-4c31-a145-0e685306d168      Marlins         Cubs
#
# [2 rows x 3 columns]

# %%
df1.merge(df2, on="gameId", how="outer")
# Out:
# HTML(value='Query job 07ee6beb-b805-4ba9-8cb2-174d4e62ddfb is DONE. 193.8 kB processed. <a target="_blank" hre…
# HTML(value='Query job ced45fc3-cfdb-4cd0-96ef-16a29d8d8f0b is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  homeTeamName awayTeamName
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43        Braves         <NA>
# 3   8fbec734-a15a-42ab-8d51-60790de7750b        Braves         <NA>
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd      Phillies         <NA>
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  Diamondbacks         <NA>
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce     Athletics         <NA>
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d     Athletics         <NA>
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01       Rockies         <NA>
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba     Cardinals         <NA>
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6     Cardinals         <NA>
# 11  46463c50-0f5c-4dca-a661-dd194464e791     Cardinals         <NA>
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f       Pirates         <NA>
# 13  387630a3-a894-4327-baa1-b24ec1a654d9       Pirates         <NA>
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556        Giants         <NA>
# 15  34444c94-03ec-4d12-96af-68b8f399a22f          Reds         <NA>
# 16  9580bffe-22e1-4975-978b-1b13e7505193          Reds         <NA>
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3          Reds         <NA>
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90          Reds         <NA>
# 19  303703bb-b55f-476d-8faf-bf582169fb1d        Padres         <NA>
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61     Nationals         <NA>
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c       Brewers         <NA>
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252       Brewers         <NA>
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923       Brewers         <NA>
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956        Astros         <NA>
# ...
#
# [2431 rows x 3 columns]

# %%
df1.merge(df2, on="gameId", how="left")
# Out:
# HTML(value='Query job 60335c33-acc9-4a4a-9e08-190fe67ad60e is DONE. 193.8 kB processed. <a target="_blank" hre…
# HTML(value='Query job 8c4e016f-429d-4591-8956-56fb18676334 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  homeTeamName awayTeamName
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43        Braves         <NA>
# 3   8fbec734-a15a-42ab-8d51-60790de7750b        Braves         <NA>
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd      Phillies         <NA>
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  Diamondbacks         <NA>
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce     Athletics         <NA>
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d     Athletics         <NA>
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01       Rockies         <NA>
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba     Cardinals         <NA>
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6     Cardinals         <NA>
# 11  46463c50-0f5c-4dca-a661-dd194464e791     Cardinals         <NA>
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f       Pirates         <NA>
# 13  387630a3-a894-4327-baa1-b24ec1a654d9       Pirates         <NA>
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556        Giants         <NA>
# 15  34444c94-03ec-4d12-96af-68b8f399a22f          Reds         <NA>
# 16  9580bffe-22e1-4975-978b-1b13e7505193          Reds         <NA>
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3          Reds         <NA>
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90          Reds         <NA>
# 19  303703bb-b55f-476d-8faf-bf582169fb1d        Padres         <NA>
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61     Nationals         <NA>
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c       Brewers         <NA>
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252       Brewers         <NA>
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923       Brewers         <NA>
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956        Astros         <NA>
# ...
#
# [2431 rows x 3 columns]

# %%
df1.merge(df2, on="gameId", how="right")
# Out:
# HTML(value='Query job 948a3d0b-1c3d-479b-b54f-9a2b2062380e is DONE. 193.8 kB processed. <a target="_blank" hre…
# HTML(value='Query job 20d2a8bb-a876-4729-a439-8c8bbf591051 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                  gameId homeTeamName awayTeamName
# 0  e14b6493-9e7f-404f-840a-8a680cc364bf      Marlins         Cubs
# 1  1f32b347-cbcb-4c31-a145-0e685306d168      Marlins         Cubs
#
# [2 rows x 3 columns]

# %% [markdown]
# ### Concat two DFs

# %%
bpd.concat([df, df])
# Out:
# HTML(value='Query job ea340371-7874-4590-bb5e-f747f81397de is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job 5c35116b-1c4a-4cc1-9ddd-172083d09490 is DONE. 193.8 kB processed. <a target="_blank" hre…
#                                   gameId  year  homeTeamName awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [4862 rows x 5 columns]

# %% [markdown]
# ### Access column through property

# %%
df.homeTeamName
# Out:
# HTML(value='Query job 79bc2f65-5c7e-470d-b30e-a959838f0ed9 is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job 9de0da3d-b43c-4381-8ecb-5b8c6d9d2c8b is DONE. 193.8 kB processed. <a target="_blank" hre…
# 0          Marlins
# 1          Marlins
# 2           Braves
# 3           Braves
# 4         Phillies
# 5     Diamondbacks
# 6        Athletics
# 7        Athletics
# 8          Rockies
# 9        Cardinals
# 10       Cardinals
# 11       Cardinals
# 12         Pirates
# 13         Pirates
# 14          Giants
# 15            Reds
# 16            Reds
# 17            Reds
# 18            Reds
# 19          Padres
# 20       Nationals
# 21         Brewers
# 22         Brewers
# 23         Brewers
# 24          Astros
# Name: homeTeamName, dtype: string

# %% [markdown]
# ### Retrieve SQL

# %%
print(df1.merge(df2, on="gameId", how="inner").sql[0])
# Out:
# W

# %% [markdown]
# ### Special Column Names

# %%
df.rename(columns={"homeTeamName": "HOME    TEAM"})
# Out:
# HTML(value='Query job 15cdbf31-e68a-41f0-9c5b-ea4ce49345f0 is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job 1e56a960-3fcd-421a-8500-bc1c099ae7a1 is DONE. 0 Bytes processed. <a target="_blank" href…
#                                   gameId  year  HOME    TEAM awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros         Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [2431 rows x 5 columns]

# %%
df.rename(columns={"homeTeamName": "homeTeam!@#$%col"})
# Out:
# HTML(value='Query job f21ef830-99b1-4fce-ab9a-378e12a04587 is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job 88f63cc1-9691-4e6c-8acf-650f31ab8560 is DONE. 0 Bytes processed. <a target="_blank" href…
#                                   gameId  year homeTeam!@#$%col awayTeamName  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016          Marlins         Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016          Marlins         Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016           Braves         Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016           Braves         Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016         Phillies         Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016     Diamondbacks         Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016        Athletics         Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016        Athletics         Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016          Rockies         Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016        Cardinals         Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016        Cardinals         Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016        Cardinals         Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016          Pirates         Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016          Pirates         Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016           Giants         Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016             Reds         Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016             Reds         Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016             Reds         Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016             Reds         Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016           Padres         Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016        Nationals         Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016          Brewers         Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016          Brewers         Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016          Brewers         Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016           Astros         Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [2431 rows x 5 columns]

# %%
df3 = df.rename(columns={"homeTeamName": "team", "awayTeamName": "team"})
df3
# Out:
# HTML(value='Query job 6f6e1d12-4202-434a-908a-3d0b34e70656 is DONE. 0 Bytes processed. <a target="_blank" href…
# HTML(value='Query job 05ec231e-a7f0-4e41-ad60-5d8136a2e148 is DONE. 0 Bytes processed. <a target="_blank" href…
#                                   gameId  year          team  team  \
# 0   e14b6493-9e7f-404f-840a-8a680cc364bf  2016       Marlins  Cubs
# 1   1f32b347-cbcb-4c31-a145-0e685306d168  2016       Marlins  Cubs
# 2   0c2292d1-7398-48be-bf8e-b41dad5e1a43  2016        Braves  Cubs
# 3   8fbec734-a15a-42ab-8d51-60790de7750b  2016        Braves  Cubs
# 4   89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd  2016      Phillies  Cubs
# 5   6a83e76c-dc0d-4924-9d3d-a2e7e0ab5b52  2016  Diamondbacks  Cubs
# 6   76ea8662-c7e6-4c38-8f2a-efe373e428ce  2016     Athletics  Cubs
# 7   66fad23d-6e89-4f99-be29-d49b6e94f95d  2016     Athletics  Cubs
# 8   d977367c-cf0c-4687-95a0-eb4542efcb01  2016       Rockies  Cubs
# 9   a87070ff-1084-43ca-a7ba-69278f93ecba  2016     Cardinals  Cubs
# 10  ea6b350d-3c1d-4737-878d-4465f66999f6  2016     Cardinals  Cubs
# 11  46463c50-0f5c-4dca-a661-dd194464e791  2016     Cardinals  Cubs
# 12  59134e6d-9d13-49aa-978e-c3c2300eb90f  2016       Pirates  Cubs
# 13  387630a3-a894-4327-baa1-b24ec1a654d9  2016       Pirates  Cubs
# 14  5d084e13-94fd-4995-b95a-4801ea3ed556  2016        Giants  Cubs
# 15  34444c94-03ec-4d12-96af-68b8f399a22f  2016          Reds  Cubs
# 16  9580bffe-22e1-4975-978b-1b13e7505193  2016          Reds  Cubs
# 17  645e6a08-afd6-4677-a5c9-01ef446b0cf3  2016          Reds  Cubs
# 18  08981bd8-d1d7-48e1-8668-9098b8f7fe90  2016          Reds  Cubs
# 19  303703bb-b55f-476d-8faf-bf582169fb1d  2016        Padres  Cubs
# 20  71ab82a4-6e07-430a-b695-1af3bc42ea61  2016     Nationals  Cubs
# 21  d1a110c2-f6c8-4029-bcd8-2f8a01e1561c  2016       Brewers  Cubs
# 22  6d111b57-fa0b-4f24-82df-ff33a26f0252  2016       Brewers  Cubs
# 23  a97e9539-bbbd-4e03-bf15-f25ea2c1d923  2016       Brewers  Cubs
# 24  dc0c9218-505c-4725-8c0c-40b72cca0956  2016        Astros  Cubs
#
#     duration_minutes
# 0                187
# 1                189
# 2                165
# 3                222
# 4                164
# 5                201
# 6                173
# 7                176
# 8                180
# 9                157
# 10               218
# 11               160
# 12               178
# 13               205
# 14               197
# 15               198
# 16               188
# 17               188
# 18               194
# 19               175
# 20               257
# 21               178
# 22               171
# 23               248
# 24               174
# ...
#
# [2431 rows x 5 columns]

# %%
df3["team"]
# Out:
# HTML(value='Query job f4b90f3c-381e-470d-8416-54f31f1fbb3a is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job 5cd5e48d-8b02-4500-94cd-cbd2ee91957e is DONE. 193.8 kB processed. <a target="_blank" hre…
#             team  team
# 0        Marlins  Cubs
# 1        Marlins  Cubs
# 2         Braves  Cubs
# 3         Braves  Cubs
# 4       Phillies  Cubs
# 5   Diamondbacks  Cubs
# 6      Athletics  Cubs
# 7      Athletics  Cubs
# 8        Rockies  Cubs
# 9      Cardinals  Cubs
# 10     Cardinals  Cubs
# 11     Cardinals  Cubs
# 12       Pirates  Cubs
# 13       Pirates  Cubs
# 14        Giants  Cubs
# 15          Reds  Cubs
# 16          Reds  Cubs
# 17          Reds  Cubs
# 18          Reds  Cubs
# 19        Padres  Cubs
# 20     Nationals  Cubs
# 21       Brewers  Cubs
# 22       Brewers  Cubs
# 23       Brewers  Cubs
# 24        Astros  Cubs
# ...
#
# [2431 rows x 2 columns]

# %% [markdown]
# ### Binary Operation

# %%
df4 = df[["year", "duration_minutes"]]
df4
# Out:
# HTML(value='Query job 6b1cf632-7764-49ba-bd5d-cdf31c47e430 is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job baa31010-2426-4ea5-9527-8f55473a3f41 is DONE. 193.8 kB processed. <a target="_blank" hre…
#     year  duration_minutes
# 0   2016               187
# 1   2016               189
# 2   2016               165
# 3   2016               222
# 4   2016               164
# 5   2016               201
# 6   2016               173
# 7   2016               176
# 8   2016               180
# 9   2016               157
# 10  2016               218
# 11  2016               160
# 12  2016               178
# 13  2016               205
# 14  2016               197
# 15  2016               198
# 16  2016               188
# 17  2016               188
# 18  2016               194
# 19  2016               175
# 20  2016               257
# 21  2016               178
# 22  2016               171
# 23  2016               248
# 24  2016               174
# ...
#
# [2431 rows x 2 columns]

# %%
df4 + 1
# Out:
# HTML(value='Query job 62ffb914-e1fb-4b12-adb5-09b431e06acf is DONE. 174.4 kB processed. <a target="_blank" hre…
# HTML(value='Query job 2eaceff3-b00c-42d0-883f-fbe85a70f49b is DONE. 193.8 kB processed. <a target="_blank" hre…
#     year  duration_minutes
# 0   2017               188
# 1   2017               190
# 2   2017               166
# 3   2017               223
# 4   2017               165
# 5   2017               202
# 6   2017               174
# 7   2017               177
# 8   2017               181
# 9   2017               158
# 10  2017               219
# 11  2017               161
# 12  2017               179
# 13  2017               206
# 14  2017               198
# 15  2017               199
# 16  2017               189
# 17  2017               189
# 18  2017               195
# 19  2017               176
# 20  2017               258
# 21  2017               179
# 22  2017               172
# 23  2017               249
# 24  2017               175
# ...
#
# [2431 rows x 2 columns]

# %% [markdown]
# ### Download the result as (in-memory) pandas DataFrame

# %%
dfp = df4.to_pandas()
dfp
# Out:
# HTML(value='Query job f3b7ff8a-ffdc-4f4c-91d3-6c2c702c373d is DONE. 193.8 kB processed. <a target="_blank" hre…
#       year  duration_minutes
# 0     2016               187
# 1     2016               189
# 2     2016               165
# 3     2016               222
# 4     2016               164
# ...    ...               ...
# 2426  2016               156
# 2427  2016               185
# 2428  2016               243
# 2429  2016               184
# 2430  2016               185
#
# [2431 rows x 2 columns]
